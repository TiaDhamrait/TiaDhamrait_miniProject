# %% [markdown]
# # Multi-Model Training Notebook

# %%
# Mount Drive -- your code and dataset should already be uploaded here
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/drive/MyDrive/<path-to-your-project-folder>

# %%
# !pip install -r requirements.txt

# %%
DATA_DIR = '/content/drive/MyDrive/<path-to-microseg>'
CKPT_DIR = '/content/drive/MyDrive/<results-folder>'

# %%
# See which models are available and read their pros/cons before picking your >= 3
# !python run.py --list_models

# %%
MODEL = 'unet'  # change to whichever model you're training -- must match a key from --list_models
# !python run.py --mode train --data_dir {DATA_DIR} --model_architecture {MODEL} --ckpt_dir {CKPT_DIR}/{MODEL}

# %%
# !python run.py --mode eval --data_dir {DATA_DIR} --model_architecture {MODEL} --checkpoint {CKPT_DIR}/{MODEL}/best_model.pt

# %% [markdown]
# Repeat the last two cells with a different `MODEL` for each architecture you complete, then compare results across models in your report.
